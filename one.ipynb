# %%
import pandas as pd

# %%
df=pd.read_csv("training sample.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df=pd.read_csv("training sample.csv")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv("training sample.csv", encoding="latin1")

# %%
df.head()
# Out:
#                    Problem      Category
# 0     Fault Issue Question  Fault-Report
# 1  Help with failure issue  Fault-Report
# 2             Fix my error  Fault-Report
# 3  I want Help with defect  Fault-Report
# 4          I have an issue  Fault-Report

# %%
df.Category.value_counts()
# Out:
# Category
# Fault-Report           61
# Farewell               61
# Product-Info-PEOTV     60
# Product-Info-voice     60
# ExtraGB                60
# Product-Info-FIBRE     60
# Product-Info-ADSL      60
# New-Connection         60
# Customer-Care-Agent    60
# Billing-info           60
# Welcome                60
# Name: count, dtype: int64

# %%
df['category_num'] = df.Category.map({

    'Fault-Report':0,
    'Product-Info-PEOTV':1,
    'Product-Info-voice':2,
    'Product-Info-ADSL':3,
    'Product-Info-FIBRE':4,
    'ExtraGB':5,
    'New-Connection':6,
    'Customer-Care-Agent':7,
    'Billing-info':8,
    'Welcome': 9,
    'Farewell':10
    
})

# %%
df.head()
# Out:
#                    Problem      Category  category_num
# 0     Fault Issue Question  Fault-Report             0
# 1  Help with failure issue  Fault-Report             0
# 2             Fix my error  Fault-Report             0
# 3  I want Help with defect  Fault-Report             0
# 4          I have an issue  Fault-Report             0

# %%
df
# Out:
#                             Problem      Category  category_num
# 0              Fault Issue Question  Fault-Report             0
# 1           Help with failure issue  Fault-Report             0
# 2                      Fix my error  Fault-Report             0
# 3           I want Help with defect  Fault-Report             0
# 4                   I have an issue  Fault-Report             0
# ..                              ...           ...           ...
# 657    Im out, Mira, see you later      Farewell            10
# 658   Mira, thanks, Im signing off      Farewell            10
# 659      Mira, have a nice day, bye      Farewell            10
# 660  Bye, Mira, Ill come back soon      Farewell            10
# 661  Mira, see you later, take care      Farewell            10
#
# [662 rows x 3 columns]

# %%
rows_with_nan = df[df.isnull().any(axis=1)]

# %%
print(rows_with_nan)
# Out:
# Empty DataFrame
# Columns: [Problem, Category, category_num]
# Index: []

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test =train_test_split(

    df.Problem,
    df.category_num,
    test_size=0.2,
    random_state=2022,
    stratify=df.category_num
)

# %%
print(X_train.shape)
# Out:
# (529,)

# %%
X_train.head()
# Out:
# 92               Is Peo TV satisfactory
# 491       Can I see my account history?
# 505    I want my charge sheeting report
# 257               ADSL speed comparison
# 238         wanna add 6GB to my package
# Name: Problem, dtype: object

# %%
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline

clf =Pipeline([
    ('vectorizor', CountVectorizer()),
    ('nb', MultinomialNB())
])

clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizor', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred =clf.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        12
#            1       1.00      1.00      1.00        12
#            2       1.00      0.92      0.96        12
#            3       1.00      0.92      0.96        12
#            4       0.80      1.00      0.89        12
#            5       1.00      1.00      1.00        12
#            6       1.00      0.83      0.91        12
#            7       1.00      0.92      0.96        12
#            8       1.00      1.00      1.00        12
#            9       1.00      1.00      1.00        12
#           10       1.00      1.00      1.00        13
#
#     accuracy                           0.96       133
#    macro avg       0.97      0.96      0.96       133
# weighted avg       0.97      0.96      0.96       133

# %%
import joblib

joblib.dump(clf,'model_joblib1')
# Out:
# ['model_joblib1']
